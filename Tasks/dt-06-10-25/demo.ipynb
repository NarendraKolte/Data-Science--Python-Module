# %%
print('hello aditya')
# Out:
# hello aditya

# %%
a,b=10,20

# %%
a,b
# Out:
# (10, 20)

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'int'>

# %%
name1="Kothrud"

# %%
type(name1)
# Out:
# str

# %%
s_name=input("Enter your name")

# %%
s_marks=input("Enter your Marks")

# %%
print(s_name)

# %%
type(s_marks)
# Out:
# str

# %%
s_marks=int(s_marks)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 s_marks=int(s_marks)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
type(s_marks)
# Out:
# int

# %%
marks=input("enter the marks")
print(marks)
marks=int(marks)
print(type(marks))
# Out:
# 90
# <class 'int'>

# %%
st='ab'
st1="Narendra"
st2="""Today is first of 
of learning     
            python"""
st3='''Welcome to my 
first           program of 
python
'''

# %%
st
# Out:
# 'ab'

# %%
st[0]
# Out:
# 'a'

# %%
st1[2]
# Out:
# 'r'

# %%
print(st3)
# Out:
# Welcome to my
# first           program of
# python

# %%
st3[:3]
# Out:
# 'Wel'

# %%
st3[3:]
# Out:
# 'come to my \nfirst           program of \npython\n'

# %%
st1[:-1]
# Out:
# 'Narendr'

# %%
st2[::2]
# Out:
# 'Tdyi is f\nflann         pto\n'

# %%
st3[:5:2]
# Out:
# 'Wlo'

# %%
marks[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 marks[0]
#
# TypeError: 'int' object is not subscriptable

# %%
list1,type(list1)
# Out:
# ([1, 2, 3, 4, 5], list)

# %%
list1=[1,2,3,4,5]

# %%
tuple1=(1,2,3,4,4,4,4,4,5,6,7)

# %%
tuple1,type(tuple1)
# Out:
# ((1, 2, 3, 4, 4, 4, 4, 4, 5, 6, 7), tuple)

# %%
set1={1,2,3,4,4,5,6,7}

# %%
set1,type(set1)
# Out:
# ({1, 2, 3, 4, 5, 6, 7}, set)

# %%
dict1={'a':10,'b':20}
dict1,type(dict1)
# Out:
# ({'a': 10, 'b': 20}, dict)

# %%
dict1['a']
# Out:
# 10

# %%
list1[2]
# Out:
# 3

# %%
tuple1[6]
# Out:
# 4

# %%
a+b
# Out:
# 30

# %%
a-b
# Out:
# -10

# %%
b/a
# Out:
# 2.0

# %%
b//a
# Out:
# 2

# %%
2**3
# Out:
# 8

# %%
a<b
# Out:
# True

# %% [markdown]
# Logical Operator
# true false

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
a=10

# %%
a==10
# Out:
# True

# %%
user=input("enter the number")
passw=int(input("enter the pass"))

if user=='narendra' and passw==1234:
    print("Logged In")

else:
    print("Wrong Cridentials")
# Out:
# Logged In

# %%
mark=int(input("enter the marks"))

if mark<=80 and mark>=90:
    print("Grade A")
elif mark<=80:
    print("Grade B")
elif mark<=65:
    print("Grade C")
elif mark<=45:
    print("Grade D")
else:
    print("Fail")
# Out:
# Fail

# %% [markdown]
# 1. If name = ''' Hi How are you? Starterd learning python. It's really interesting.''' Then what is the output of following code • name[:] • name[-10:-5] • name[3:12] • name[12:3] • name[5,6] • name[-4:-12]

# %%
name='''Hi How are you? Starterd learning python. It's really interesting.'''

# %%
name[:]
# Out:
# " Hi How are you? Starterd learning python. It's really interesting."

# %%
name[-10:-5]
# Out:
# 'teres'

# %%
name[3:12]
# Out:
# 'How are y'

# %%
name[12:3]
# Out:
# ''

# %%
name[5:6]
# Out:
# 'w'

# %%
name[-4:-12]
# Out:
# ''

# %% [markdown]
# . L1 = [‘a’ , ‘b’, 20, 30, ‘t’, 100, 300, 400, ‘happy’, ‘major’] a. L1[:] b. How to extract value “Happy” based on index and negative index c. How to check type of data in list at 4th position d. Extract values for 100, 300, 400

# %%
L1 = ['a' , 'b', 20, 30, 't', 100, 300, 400, 'happy', 'major']

# %%
#a. L1[:]
L1[:]
# Out:
# ['a', 'b', 20, 30, 't', 100, 300, 400, 'happy', 'major']

# %%
#b. How to extract value “Happy” based on index and negative index
L1[8:-1]
# Out:
# ['happy']

# %%
#c. How to check type of data in list at 4th position

# %%
print(L1[4])
type(L1[4])
# Out:
# t
# str

# %%
#d. Extract values for 100, 300, 400
L1[5:-2]
# Out:
# [100, 300, 400]

# %% [markdown]
# 6. Ask user to enter the marks and define if the user got distinction, first class, second class, pass, Fails If marks are more than 80 output must be “You got distinction” For marks more than 60 output must be “You got First class” Marks more than 40 will display “You got second class” Marks more than or equal to 35 “PASS” Otherwise Fail

# %%
user=int(input("enter the marks"))

if user>=80 and user<=100:
    print("You got distinction")
elif user>=60 and user<=80:
    print("You got First class")
elif user>=40 and user<=60:
    print("You got Second class")
else:
    print("Fail")
# Out:
# You got distinction
