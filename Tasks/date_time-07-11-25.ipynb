# %%
from datetime import datetime,date,time

# %%
d1=datetime.now()
d1
# Out:
# datetime.datetime(2025, 11, 7, 11, 47, 37, 297141)

# %%
d1=date(year=2000,month=10,day=31)
print(d1,type(d1))
d2=date(year=2007,month=4,day=30)
print(d2,type(d2))
# Out:
# 2000-10-31 <class 'datetime.date'>
# 2007-04-30 <class 'datetime.date'>

# %%
import time
print("LOGIN",datetime.now())
time.sleep(60*2)
print("LOGOUT",datetime.now())
# Out:
# LOGIN 2025-11-07 11:57:18.348001
# LOGOUT 2025-11-07 11:59:18.348381
