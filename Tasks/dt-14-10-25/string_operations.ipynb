# %% [markdown]
# String Operations

# %%
val="DATA"
val
# Out:
# 'DATA'

# %%
"B"+val[1:]
# Out:
# 'BATA'

# %%
val[:2]+"C"+val[3:]
# Out:
# 'DACA'

# %%
val[:2]
# Out:
# 'DA'

# %%
val[3:]
# Out:
# 'A'

# %%
li=[]
for i in val:
    if i=="D":
        i="B"
    print(i,end="")
    li.append(i)
# Out:
# BATA

# %%
"-"+"#"
# Out:
# '-#'

# %%
"**".join(val)
# Out:
# 'D**A**T**A'

# %%
for i in range(6):
    print("*"*i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
next_var="**".join(val)
next_var
# Out:
# 'D**A**T**A'

# %%
next_var[::3]
# Out:
# 'DATA'

# %%
for i in next_var:
    if i=='*':
        continue
    print(i,end='')
# Out:
# DATA

# %% [markdown]
# String Addition and Multiplication is possible

# %%
name="Narendra"

# %%
var=123232

# %%
name.replace("N","D")
# Out:
# 'Darendra'

# %%
name.isdigit()
# Out:
# False

# %%
count=0
for letter in 'Hello World How Are You:':
    if letter=='H':
        letter=='W'
    print(letter,end='')
    count=count+1

print(count," Letter Found")
# Out:
# Hello World How Are You:24  Letter Found

# %%
print('"Hello" ,What\'s the weather')
# Out:
# "Hello" ,What's the weather

# %%
print('He Said,\n"What\'s there?"')
# Out:
# He Said,
# "What's there?"

# %%
name="NArendra"

# %%
name.lower()
# Out:
# 'narendra'

# %%
name.upper()
# Out:
# 'NARENDRA'

# %%
name.capitalize()
# Out:
# 'Narendra'
