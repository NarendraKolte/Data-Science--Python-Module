# %%
v1=lambda:"hii"

# %%
v1()
# Out:
# 'hii'

# %%
type(v1)
# Out:
# function

# %%
v2=lambda Y:"HI {}".format(Y)
v2('rajani')
# Out:
# 'HI rajani'

# %%
va=lambda x : x+100

# %%
va(60)
# Out:
# 160

# %%
var=lambda x,y :(x+y,x-y,x*y,y/x)

# %%
var(2,3)
# Out:
# (5, -1, 6, 1.5)

# %%
ar=lambda x,y :{"add":x+y,"sub":x-y,"mul":x*y,"division":y/x}

# %% [markdown]
# Data engineering core
#
# pandas
# pollars
# pyspark-spark data frame

# %%
import pandas as pd
ser1=pd.Series(var(4,3))
ser1
# Out:
# 0     7.00
# 1     1.00
# 2    12.00
# 3     0.75
# dtype: float64

# %%
ser1.apply(lambda x:x+1)
# Out:
# 0     8.00
# 1     2.00
# 2    13.00
# 3     1.75
# dtype: float64

# %%
ir = lambda x: print(f"Even number: {x}") if x%2==0 else print(f"Odd number: {x}")

# %%
ir(6)
# Out:
# Even number: 6

# %%
[i if i%2==0 else i*100 for i in range(10)]
# Out:
# [0, 100, 2, 300, 4, 500, 6, 700, 8, 900]

# %%
greeting=lambda name:"Hello {}".format(name)
greeting("Sameer")
# Out:
# 'Hello Sameer'

# %%
irs=lambda x:len(x)
irs("Narendra")
# Out:
# 8

# %%
irs1 = lambda x: "Invalid datatype" if not isinstance(x, (int, float, bool)) else "Correct Input" "Correct Input" "Correct Input"

# %%
irs1(2)
# Out:
# 'Correct InputCorrect InputCorrect Input'

# %% [markdown]
# Map has first argument as function and second argument as iterative value
#
# map(def/system define/lambda,iterative )

# %%
l1=["niraj",'narendra',10000,{3,4,5,6,7},67,"Harsh","Nody","Pikachuuu"]
len(l1)
# Out:
# 8

# %%
l2=["niraj",'narendra',"Harsh","Nody","Pikachuuu"]
len(l2)
# Out:
# 5

# %%
list(map(length2,l1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 list(map(length2,l1))
#
# NameError: name 'length2' is not defined

# %%
list(map(type,l1))
# Out:
# [str, str, int, set, int, str, str, str]

# %%
l3=['a','aa','aaaa','aaaaaaa','err','mean absolute eroor']

# %%
list(filter(lambda x:len(x)>6,l3))
# Out:
# ['aaaaaaa', 'mean absolute eroor']

# %%
l1=[2,3,4,4,6,7,8,9,6,33,36,9]

# %%
list(filter(lambda x:x%2==0,l1))
# Out:
# [2, 4, 4, 6, 8, 6, 36]

# %%
l2=['one',2,'three',4]

# %%
list(map(lambda x:type(x)==str,l2))
# Out:
# [True, False, True, False]

# %%
from functools import reduce

# %%
summation=reduce((lambda x,y:x+y),[1,2,3,4,5])
summation
# Out:
# 15
